# %%
import rayReader as rr
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/mjmarsee/.local/lib/python3.10/site-packages/numpy/core/getlimits.py:542: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
with rr.Rays("ray_dictionary.h5") as r:
    ray, angle = r.get_ray_from_source_zenith(60, mode="deg")
    ref_angle = r.source_zenith_to_launch_angle(60,mode='deg')

print(ref_angle)
print(angle)
# Out:
# 135.70061656980485
# 135.5

# %%
with rr.Rays("ray_dictionary.h5") as r:
    ray_deg, ang_deg = r.get_ray_from_source_zenith(45, mode="deg")
    ray_rad, ang_rad = r.get_ray_from_source_zenith(np.pi/4, mode="rad")


    _, _, i_deg = r.get_ray_from_source_zenith(45, mode="deg", return_index=True)
    _, _, i_rad = r.get_ray_from_source_zenith(np.pi/4, mode="rad", return_index=True)


print('Position of each ray in dictionary: ',i_deg, i_rad)
diff = np.max(np.abs(ray_deg - ray_rad))
print(diff)
# Out:
# Position of each ray in dictionary:  110 110
# 0.0

# %%
r_deg, z_deg, t_deg = ray_deg
r_rad, z_rad, t_rad = ray_rad



plt.plot(r_deg,z_deg,label=f'Launch Angle (From +z^): {ang_deg} deg')
plt.xlabel('r [m]')
plt.ylabel('z [m]')

plt.legend()
plt.show()
